# %%
import itertools

string = input('String a ser permutada: ')
result = itertools.permutations(string, len(string))

for i in result:
    print(''.join(i))
# Out:
# String a ser permutada: sucesso
# sucesso
# sucesos
# sucesso
# sucesos
# suceoss
# suceoss
# sucseso
# sucseos
# sucsseo
# sucssoe
# sucsoes
# sucsose
# sucseso
# sucseos
# sucsseo
# sucssoe
# sucsoes
# sucsose
# sucoess
# sucoess
# sucoses
# sucosse
# sucoses
# sucosse
# suecsso
# suecsos
# suecsso
# suecsos
# suecoss
# suecoss
# suescso
# suescos
# suessco
# suessoc
# suesocs
# suesosc
# suescso
# suescos
# suessco
# suessoc
# suesocs
# suesosc
# sueocss
# sueocss
# sueoscs
# sueossc
# sueoscs
# sueossc
# susceso
# susceos
# suscseo
# suscsoe
# suscoes
# suscose
# susecso
# susecos
# susesco
# susesoc
# suseocs
# suseosc
# sussceo
# susscoe
# susseco
# susseoc
# sussoce
# sussoec
# susoces
# susocse
# susoecs
# susoesc
# susosce
# susosec
# susceso
# susceos
# suscseo
# suscsoe
# suscoes
# suscose
# susecso
# susecos
# susesco
# susesoc
# suseocs
# suseosc
# sussceo
# susscoe
# susseco
# susseoc
# sussoce
# sussoec
# susoces
# susocse
# susoecs
# susoesc
# susosce
# susosec
# ...
